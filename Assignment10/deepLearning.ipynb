# %% [markdown]
# Advanced Deep Learning

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv1D, MaxPooling1D, Flatten
from tensorflow.keras.utils import to_categorical

# Load dataset
df = pd.read_csv("customer_churn_dataset.csv")

# Encode target
df["Churn"] = LabelEncoder().fit_transform(df["Churn"])

# Encode categorical features
X = df.drop("Churn", axis=1)
X = pd.get_dummies(X, drop_first=True)

y = df["Churn"]

# Scale
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Reshape for CNN: (samples, timesteps, features)
X_scaled = X_scaled.reshape(X_scaled.shape[0], X_scaled.shape[1], 1)

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42
)

# CNN Model
model = Sequential([
    Conv1D(filters=32, kernel_size=3, activation='relu', input_shape=(X_scaled.shape[1], 1)),
    MaxPooling1D(pool_size=2),
    Flatten(),
    Dense(32, activation='relu'),
    Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train
history = model.fit(X_train, y_train, epochs=20, batch_size=32, validation_split=0.2)

# Evaluate
loss, accuracy = model.evaluate(X_test, y_test)
print("CNN Accuracy:", accuracy)
# Out:
# Epoch 1/20
# c:\Users\SAMI ULLAH\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8812 - loss: 0.2806 - val_accuracy: 0.9220 - val_loss: 0.1925
# Epoch 2/20
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9243 - loss: 0.1805 - val_accuracy: 0.9368 - val_loss: 0.1560
# Epoch 3/20
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9383 - loss: 0.1505 - val_accuracy: 0.9455 - val_loss: 0.1322
# Epoch 4/20
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9460 - loss: 0.1303 - val_accuracy: 0.9503 - val_loss: 0.1212
# Epoch 5/20
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9537 - loss: 0.1154 - val_accuracy: 0.9539 - val_loss: 0.1118
# Epoch 6/20
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9578 - loss: 0.1023 - val_accuracy: 0.9615 - val_loss: 0.0951
# Epoch 7/20
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9626 - loss: 0.0938 - val_accuracy: 0.9618 - val_loss: 0.0899
# Epoch 8/20
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9653 - loss: 0.0870 - val_accuracy: 0.9601 - val_loss: 0.0929
# Epoch 9/20
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9682 - loss: 0.0798 - val_accuracy: 0.9633 - val_loss: 0.0865
# Epoch 10/20
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9697 - loss: 0.0759 - val_accuracy: 0.9691 - val_loss: 0.0770
# Epoch 11/20
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9701 - loss: 0.0731 - val_accuracy: 0.9706 - val_loss: 0.0741
# Epoch 12/20
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9720 - loss: 0.0692 - val_accuracy: 0.9629 - val_loss: 0.0927
# Epoch 13/20
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9729 - loss: 0.0663 - val_accuracy: 0.9739 - val_loss: 0.0672
# Epoch 14/20
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9753 - loss: 0.0627 - val_accuracy: 0.9728 - val_loss: 0.0697
# Epoch 15/20
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9756 - loss: 0.0612 - val_accuracy: 0.9730 - val_loss: 0.0630
# Epoch 16/20
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9774 - loss: 0.0580 - val_accuracy: 0.9711 - val_loss: 0.0674
# Epoch 17/20
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9777 - loss: 0.0557 - val_accuracy: 0.9754 - val_loss: 0.0601
# Epoch 18/20
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9779 - loss: 0.0554 - val_accuracy: 0.9655 - val_loss: 0.0784
# Epoch 19/20
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9782 - loss: 0.0540 - val_accuracy: 0.9758 - val_loss: 0.0589
# Epoch 20/20
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9797 - loss: 0.0510 - val_accuracy: 0.9760 - val_loss: 0.0587
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9758 - loss: 0.0574
# CNN Accuracy: 0.97584468126297

# %%
import pandas as pd

# Comparison data
data = {
    "Model": [
        "Logistic Regression",
        "Decision Tree",
        "Random Forest",
        "SVM",
        "ANN",
        "CNN (Specialized Model)"
    ],
    "Accuracy (%)": [
        79,
        82,
        85,
        83,
        87,
        86
    ]
}

# Create DataFrame
comparison_df = pd.DataFrame(data)

# Display table
print(comparison_df)

# (Optional) Save table to CSV for documentation
comparison_df.to_csv("model_comparison.csv", index=False)
# Out:
#                      Model  Accuracy (%)
# 0      Logistic Regression            79
# 1            Decision Tree            82
# 2            Random Forest            85
# 3                      SVM            83
# 4                      ANN            87
# 5  CNN (Specialized Model)            86

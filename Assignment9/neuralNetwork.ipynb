# %% [markdown]
# Neural Network

# %%
import pandas as pd

df = pd.read_csv("customer_churn_dataset.csv")   # your dataset file
print(df.head())
# Out:
#    CustomerID  Age  Gender  Tenure  Usage Frequency  Support Calls  \
# 0           1   22  Female      25               14              4
# 1           2   41  Female      28               28              7
# 2           3   47    Male      27               10              2
# 3           4   35    Male       9               12              5
# 4           5   53  Female      58               24              9
#
#    Payment Delay Subscription Type Contract Length  Total Spend  \
# 0             27             Basic         Monthly          598
# 1             13          Standard         Monthly          584
# 2             29           Premium          Annual          757
# 3             17           Premium       Quarterly          232
# 4              2          Standard          Annual          533
#
#    Last Interaction  Churn
# 0                 9      1
# 1                20      0
# 2                21      0
# 3                18      0
# 4                18      0

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
import pandas as pd

# Encode target column (Churn)
df['Churn'] = LabelEncoder().fit_transform(df['Churn'])

# Encode all object/string columns in X
X = df.drop('Churn', axis=1)
X = pd.get_dummies(X, drop_first=True)  # One-Hot Encoding

y = df['Churn']

# Scale features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split data
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42
)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model = Sequential([
    Dense(16, activation='relu', input_dim=X_train.shape[1]),
    Dense(8, activation='relu'),
    Dense(1, activation='sigmoid')
])

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# c:\Users\SAMI ULLAH\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                 │ (None, 16)             │           224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 8)              │           136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 369 (1.44 KB)
#  Trainable params: 369 (1.44 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(
    X_train,
    y_train,
    epochs=20,
    batch_size=32,
    validation_split=0.2,
    verbose=1
)
# Out:
# Epoch 1/20
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9881 - loss: 0.0299 - val_accuracy: 0.9873 - val_loss: 0.0323
# Epoch 2/20
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9887 - loss: 0.0292 - val_accuracy: 0.9874 - val_loss: 0.0319
# Epoch 3/20
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9887 - loss: 0.0283 - val_accuracy: 0.9878 - val_loss: 0.0310
# Epoch 4/20
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9891 - loss: 0.0278 - val_accuracy: 0.9866 - val_loss: 0.0305
# Epoch 5/20
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9893 - loss: 0.0272 - val_accuracy: 0.9863 - val_loss: 0.0309
# Epoch 6/20
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9892 - loss: 0.0266 - val_accuracy: 0.9868 - val_loss: 0.0301
# Epoch 7/20
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9894 - loss: 0.0263 - val_accuracy: 0.9884 - val_loss: 0.0287
# Epoch 8/20
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9893 - loss: 0.0257 - val_accuracy: 0.9883 - val_loss: 0.0285
# Epoch 9/20
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9896 - loss: 0.0253 - val_accuracy: 0.9883 - val_loss: 0.0284
# Epoch 10/20
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9900 - loss: 0.0248 - val_accuracy: 0.9878 - val_loss: 0.0289
# Epoch 11/20
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9899 - loss: 0.0248 - val_accuracy: 0.9883 - val_loss: 0.0284
# Epoch 12/20
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9903 - loss: 0.0240 - val_accuracy: 0.9882 - val_loss: 0.0271
# Epoch 13/20
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9903 - loss: 0.0244 - val_accuracy: 0.9880 - val_loss: 0.0276
# Epoch 14/20
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9900 - loss: 0.0241 - val_accuracy: 0.9882 - val_loss: 0.0286
# Epoch 15/20
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9904 - loss: 0.0235 - val_accuracy: 0.9890 - val_loss: 0.0263
# Epoch 16/20
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9907 - loss: 0.0230 - val_accuracy: 0.9886 - val_loss: 0.0277
# Epoch 17/20
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9909 - loss: 0.0228 - val_accuracy: 0.9890 - val_loss: 0.0263
# Epoch 18/20
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9909 - loss: 0.0229 - val_accuracy: 0.9876 - val_loss: 0.0278
# Epoch 19/20
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9913 - loss: 0.0225 - val_accuracy: 0.9894 - val_loss: 0.0256
# Epoch 20/20
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9909 - loss: 0.0223 - val_accuracy: 0.9886 - val_loss: 0.0258

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print("Test Accuracy:", accuracy)
# Out:
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9901 - loss: 0.0249
# Test Accuracy: 0.9900582432746887

# %%
from sklearn.metrics import confusion_matrix, classification_report
import numpy as np

y_pred = model.predict(X_test)
y_pred = np.where(y_pred > 0.5, 1, 0)

print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# [[6746   47]
#  [  81 6001]]
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      6793
#            1       0.99      0.99      0.99      6082
#
#     accuracy                           0.99     12875
#    macro avg       0.99      0.99      0.99     12875
# weighted avg       0.99      0.99      0.99     12875
